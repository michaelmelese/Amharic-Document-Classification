# %%
import os
import pandas as pd
import re
import numpy as np
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
print(os.getcwd())
# Out:
# /Users/michaelmelese/Desktop/WSU-AI

# %%
folders=['social', 'politics', 'business', 'religion', 'sport', 'health', 'science-tech', 'law']
paths = []
for category_class in folders:
    paths.append(os.getcwd()+'/corpus/'+category_class)
documents = []
labels = []
labels_to_category = []
source=[]
for Category in range(len(paths)):
    for one_file in os.listdir(paths[Category]):        
        with open(paths[Category]+"/"+one_file,'r') as file:
            tmp = str(file.read())
            tmp = tmp.replace("\n"," ").replace('\r','')
            documents.append(tmp)
            file.close()
        source.append(" ".join(one_file.split("-")[0].split("_")))
        labels.append(folders[Category])
        labels_to_category.append(Category)
data = pd.DataFrame({'documents':documents,'category':labels_to_category, 'labels':labels, 'source': source})#
data.to_csv('document_categorization.csv')
print(len(documents), len(labels_to_category))#, len(labels_to_category))
# Out:
# 400 400

# %%
resource = pd.read_csv('document_categorization.csv')

# %%
resource=resource.drop('Unnamed: 0', axis=1)

# %%
resource[resource['category'] == 1]
# Out:
#                                             documents  category    labels  \
# 50  የፖለቲካ ጥግ ።   ኖርማን ቴቢት ።  ሎርድ አክተን ።  ፍራንሲስ ቤከን...         1  politics
# 51  የኔትዎርክ መቆራረጥ እንጂ የደንበኞች መቆራረጥ አልገጠመኝም ኢትዮ ቴሌኮም...         1  politics
# 52  ኢህአዴግ የሰላማዊ ሰልፍ መብታችንን ማረሳሳቱ ነው እንዴ ? አዳራሹ ከእኔ...         1  politics
# 53  እጩ ጠ/ሚኒስትሮች የምረጡኝ ዘመቻ ያድርጉ ! ለቀውስ ዘመን የሚመጥን ብቃ...         1  politics
# 54  መንግስት ንግዱ ቀርቶበት በቅጡ ይምራን ? መንግስት ቢዝነስ ውስጥ ሲገባ ...         1  politics
# 55  የፖለቲካ ጥግ ። የአሜሪካ ዲሞክራሲና የአሜሪካ ኢኮኖሚ ስኬታማ የነበሩት ...         1  politics
# 56  የፖለቲካ ጥግ ። የስራ ማቆም አድማን አልታገስም ። እኔ የስራ ማቆም አድ...         1  politics
# 57  3ሺ የናይሮቢ የጐዳና ተዳዳሪዎች ተሃድሶ ገቡ ! ከልጅ ልጅ ቢለዩ ። የኦ...         1  politics
# 58  አንዳንዴ ገዢ ፓርቲም በምርጫ ይሸነፋል ! በናይጀሪያ ፕሬዚዳንታዊ ምርጫ ...         1  politics
# 59  ፈረሱ ምን ሆኖ ነው እየሳቀ የሚያለቅሰው ? ያለቀሰው ከመንግስት የመጣ መ...         1  politics
# 60  የፖለቲካ ጥግ ። ሰላም መፍጠር የምትሻ ከሆነ ከወዳጆችህ ጋር ሳይሆን ከጠ...         1  politics
# 61  ፖለቲካዊ ሃሜቶች ። የአሜሪካው ፕሬዚዳንት ባራክ ኦባማ በቅርቡ በአለም የ...         1  politics
# 62  ምርጫውን ማድረግ አይቻልም ? የመጀመሪያውን ስልክ የመታው ለሚወዳቸውና ለ...         1  politics
# 63  የክፍለ ዘመኑ የኢህአዴግ አስቀያሚ ታሪክ ? ጽድቁ ቀርቶብኝ በቅጡ በኮነነ...         1  politics
# 64  የፖለቲካ ጥግ ። ወፍራም ደሞዝ ተከፋይ የአፍሪካ ፕሬዚዳንቶች !  የደቡብ...         1  politics
# 65  ከአንጋፋ የተቃዋሚ ፓርቲ አመራር ጋር የተደረገ ታሪካዊ ቃለ-ምልልስ ! ጋ...         1  politics
# 66  ጠ/ሚኒስትሩ ተቃዋሚ ፓርቲ ቢያቋቁሙስ ? ወዳጄን ካወቅሁት ጀምሮ የእስስት...         1  politics
# 67  ኢህአዴግ በአንድ ሳምንት ውስጥ ናፍቆቴን አረካልኝ ! ባለፈው ሳምንት ምን...         1  politics
# 68  ኢህአዴግ ሰልፍ የማይጠራን እኮ ኑሮአችንን ሰልፍ ስላደረገው ነው ! የታክ...         1  politics
# 69  አለም ላይ ኮሜዲ የሰሩት አምባገነኑ የኡጋንዳ መሪ ኢዲ አሚን ! ዲሞክራሲ...         1  politics
# 70  ተቃዋሚዎች እንደ ዳይኖሰር ከጠፉ መንግስትም ይጐዳል ! የተቃዋሚዎችን ጥር...         1  politics
# 71  ኢህአዴግ ሌላ አገር ያስተዳድራል እንዴ ? አረ ገና ብዙ አለ ። በአዲስ ...         1  politics
# 72  ሁሉም የየራሱን የግንቦት 20 ፍሬዎች ይናገር ! የኢህአዴግ የግንቦት 20...         1  politics
# 73  ህዝባዊ መሰረት ያለው ፓርቲ ህዝቡን አይሰልልም ! አሜሪካ ያልሰለለችው እ...         1  politics
# 74  ራእይ የሌለው መሪ አልመርጥም ! ግን እኮ እሳቸው ከ8 ሰአት በላይ የማሰ...         1  politics
# 75  አዲሱን አመት በፖለቲካ ቀልዶች ። አትጠራጠሩ ቀልድ የማያውቁ ፓርቲዎች ለ...         1  politics
# 76  የርእዮተ አለም ጨዋታ ። የአሜሪካ ዲሞክራት ሁለት ላሞች አሉህ ጐረቤትህ ...         1  politics
# 77  ወደፊት መሄዱ ይቀራል እንጂ ወደኋላማ አንመለስም ! የኔትዎርክ አለመኖር ...         1  politics
# 78  ድንጋይ እንዳይወረወር ሃሳብ መወርወርያ መድረክ ! የፖለቲካ ፓርቲዎች የት...         1  politics
# 79  የፖለቲካ ጥግ ።   የአብዛኞቹ መንግስታት መሰረት ፍርሃት ነው ። ጆን አ...         1  politics
# 80  አሁን የሚያዋጣው ከቻይናው ጋር መወዳጀት ብቻ ነው ! ጆን ኬሪ ታሳሪዎቹን...         1  politics
# 81  ህዝቡ ካድሬ እንደማያስፈልገው አረጋገጠ ! የሀዘን ብዛት አቶ መለስን ከሞ...         1  politics
# 82  አምባገነንነት እንደ ፖሊዮ ከምድረገጽ መጥፋት አለበት ! ባለፈው ሳምንት ...         1  politics
# 83  ዳውን ዳውን ኢትዮጵያ ! አዲሱ የፖለቲካ ፋሽን ። ደግነቱ ኢትዮጵያዊነት ...         1  politics
# 84  በ21ኛው ክ/ዘመን ተቃዋሚዎችን መደብደብ አይመከርም ! እንዳለፉት ሳምንታ...         1  politics
# 85  ጠ/ሚኒስትር ሃ/ማርያም ደሳለኝ ይቅርታን የደፈሩ መሪ ! ከእለት ወደ እለ...         1  politics
# 86  ከአስር ሺ ካድሬዎች አንድ ጀግና አትሌት ይሻለኛል ! የፌዴሬሽን ነገር አ...         1  politics
# 87  ሁሉንም ህዝብ ማስደሰት የሚችል መንግስት የለም ። ጓድ ሌኒን የማይወዱ ከ...         1  politics
# 88  ፈረሱ ምን ሆኖ ነው እየሳቀ የሚያለቅሰው ? አንደኛ መውጣቴ ከፍተኛ ሽልማ...         1  politics
# 89  ህዝብ ለወደደው ይገዛል ያመነውን ያነግሳል ! ላለፉት ሁለት አስርት አመታ...         1  politics
# 90  ዳያስፖራዎች የእኛ ኢትዮጵያ አልተስማማቻቸውም ! ከወር ገደማ በፊት ይመስ...         1  politics
# 91  ተቃዋሚነት የሰለቻቸው ፖለቲከኛ ምን ይላሉ ? ምናባዊ ቃለምልልስ ። ለፖለ...         1  politics
# 92  ቁምነገርና ፌዝ አለመለየት አደጋ አለው ! ኢህአዴግ ብዙ ይዘገያል እንጂ ...         1  politics
# 93  ልማታዊ መንግስታችን መፍታት ይልመድበት ! በዘንድሮ ምርጫ የሚዲያ ቅስቀሳ...         1  politics
# 94  የፖለቲካ ጥግ ። ሮበርት ፍሮስት ። አሜሪካዊ ገጣሚ ። የታሪክ ባለሙያ ማ...         1  politics
# 95  የፖለቲካ ጥግ ። ዲሞክራሲ የተሳሳተ ምርጫ የማድረግ መብት ነው ። ሰር ጆ...         1  politics
# 96  የፖለቲካ ጥግ ። የካፒታሊዝም መሰረታዊ ችግር ፍትሃዊ የሆነ የሃብት ክፍፍ...         1  politics
# 97  ለ25 አመት አገልግሎት የ25 ሚሊዮን ብር መኖሪያ ቤት ! ባለስልጣናቱ የ...         1  politics
# 98  ጠ/ሚኒስትሩ ቀላል ተናገሩ ! የመንግስት ባለስልጣናት ኔትዎርካችሁን በደን...         1  politics
# 99  ኩረጃን ለትውልድ አናወርስም የሚል ዘመቻ የግድ ነው ! የአለም አቀፍ ሆቴ...         1  politics
#
#          source
# 50  Addis Admas
# 51  Addis Admas
# 52  Addis Admas
# 53  Addis Admas
# 54  Addis Admas
# 55  Addis Admas
# 56  Addis Admas
# 57  Addis Admas
# 58  Addis Admas
# 59  Addis Admas
# 60  Addis Admas
# 61  Addis Admas
# 62  Addis Admas
# 63  Addis Admas
# 64  Addis Admas
# 65  Addis Admas
# 66  Addis Admas
# 67  Addis Admas
# 68  Addis Admas
# 69  Addis Admas
# 70  Addis Admas
# 71  Addis Admas
# 72  Addis Admas
# 73  Addis Admas
# 74  Addis Admas
# 75  Addis Admas
# 76  Addis Admas
# 77  Addis Admas
# 78  Addis Admas
# 79  Addis Admas
# 80  Addis Admas
# 81  Addis Admas
# 82  Addis Admas
# 83  Addis Admas
# 84  Addis Admas
# 85  Addis Admas
# 86  Addis Admas
# 87  Addis Admas
# 88  Addis Admas
# 89  Addis Admas
# 90  Addis Admas
# 91  Addis Admas
# 92  Addis Admas
# 93  Addis Admas
# 94  Addis Admas
# 95  Addis Admas
# 96  Addis Admas
# 97  Addis Admas
# 98  Addis Admas
# 99  Addis Admas

# %%
resource.dropna(subset = ["documents"], inplace=True)

# %%
resource
# Out:
# 400

# %%
resource.tail()

# %%
##### data_vector.shape
from sklearn.model_selection import train_test_split
sentences_train, sentences_test, y_train, y_test = train_test_split(resource['documents'], resource['category'], test_size=0.05, random_state=42)

# %%
len(sentences_train), len(sentences_test), len(y_train), len(y_test)

# %%
print("training data instance ", len(sentences_train))
print("Testing data instance ", len(sentences_test))

# %% [markdown]
# # Conversion of word to vector

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit(sentences_train)
text_vector_train = vectorizer.transform(sentences_train)
text_vector_test  = vectorizer.transform(sentences_test)

# %%
text_vector_train.shape

# %%
text_vector_test.shape

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_sample(text_vector_train, y_train.ravel())

# %%
type(text_vector_train), type(y_train_res)

# %% [markdown]
# for file in y_train.unique():
#     print(len(y_train_res[y_train_res == file]))

# %%
print(text_vector_train.shape)
print(X_train_res.shape)

# %% [markdown]
# from imblearn.over_sampling import SMOTE
# smote=SMOTE('not minority')
# vector_train_resampled, data_y_train_resampled = smote.fit_resample(vector_train, y_train)
# #SMOTE(random_state=42).fit_resample(

# %% [markdown]
# # Start of adc training using word to vector only

# %%
from sklearn.naive_bayes import MultinomialNB
multi_NB=MultinomialNB()
classifier=multi_NB.fit(X_train_res, y_train_res)

# %%
score = classifier.score(text_vector_test, y_test)

# %%
prediction = classifier.predict(text_vector_test)

# %%
len(folders)
folders=['social', 'politics', 'business', 'religion', 'sport', 'health', 'science-tech', 'law', ' ']

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
print("Accuracy : ", accuracy_score(y_test, prediction))
#print(metrics.classification_report(y_test, prediction, target_names=folders))
metrics.confusion_matrix(y_test, prediction)
#Accuracy :  0.7303765156349713

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction)

# %%
import matplotlib.pyplot as plt
import itertools
cmap = plt.cm.Blues
title = "NB Confusion Matrix"
classes = 8
normalize = False
tick_marks = np.arange(classes)
plt.imshow(cm, interpolation='nearest', cmap=cmap)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(10)
#plt.xticks(tick_marks, classes, rotation=45)
#plt.yticks(tick_marks, classes)

fmt = '.2f' if normalize else 'd'
thresh = cm.max() / 5.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# # End of adc training using word to vector only
